# %%
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("../data/finalData2.csv")
df['time'] = pd.to_datetime(df['time'])
df.drop(['oerlikon', 'time', 'Unnamed: 0'], inplace=True, axis = 1)
X,y = df.drop('city', axis = 1), df['city']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# # Fit model

# %%
reg = xgb.XGBRegressor()
reg.fit(X_train, y_train)
y_pred = reg.predict(X_test)

# %%
score = mean_squared_error(y_test, y_pred)
print(score)
# Out:
# 72.03505725463737

# %%
X_train.head()
# Out:
#         weekday  minutes_since_midnight  opened  temperature_2m (°C)  \
# 337089        5                     213   False            10.400000
# 47356         5                     405    True             4.049333
# 234984        1                      38   False            11.218333
# 58094         2                      59   False             1.297889
# 299877        2                    1086    True            14.192778
#
#         relative_humidity_2m (%)  apparent_temperature (°C)  \
# 337089                 90.557222                   9.355722
# 47356                  99.000000                   1.924667
# 234984                 55.272222                   6.091111
# 58094                  95.010556                  -1.702111
# 299877                 65.750556                  12.246389
#
#         precipitation (mm)  cloud_cover (%)  wind_speed_10m (km/h)  \
# 337089            0.455722       100.000000               5.600000
# 47356             0.000000        89.846667               4.774000
# 234984            0.000000        53.558333              23.663333
# 58094             0.000000        60.285000               6.100000
# 299877            0.000000        47.501111               9.385556
#
#         shortwave_radiation (W/m²)  is_day ()
# 337089                    0.000000        0.0
# 47356                     0.000000        0.0
# 234984                    0.000000        0.0
# 58094                     0.000000        0.0
# 299877                  247.916667        1.0

# %% [markdown]
# # Calculate for a week

# %%
df = pd.read_csv("../data/finalData2.csv")
df['time'] = pd.to_datetime(df['time'])
start = pd.to_datetime(df['time'])

# %%
df
# Out:
#         Unnamed: 0                time  city  oerlikon  weekday  \
# 0                0 2024-01-24 16:43:08   155       140        2
# 1                1 2024-01-24 16:43:38   154       140        2
# 2                2 2024-01-24 16:45:31   163       140        2
# 3                3 2024-01-24 16:46:02   163       141        2
# 4                4 2024-01-24 16:46:32   162       143        2
# ...            ...                 ...   ...       ...      ...
# 412796      412796 2024-06-27 15:57:34    76       105        3
# 412797      412797 2024-06-27 15:58:05    76       106        3
# 412798      412798 2024-06-27 15:58:35    79       106        3
# 412799      412799 2024-06-27 15:59:06    78       105        3
# 412800      412800 2024-06-27 16:00:09    77       106        3
#
#         minutes_since_midnight  opened  temperature_2m (°C)  \
# 0                         1003    True            11.496778
# 1                         1003    True            11.490944
# 2                         1005    True            11.468972
# 3                         1006    True            11.462944
# 4                         1006    True            11.457111
# ...                        ...     ...                  ...
# 412796                     957    True            25.687833
# 412797                     958    True            25.690417
# 412798                     958    True            25.692917
# 412799                     959    True            25.695500
# 412800                     960    True            25.701750
#
#         relative_humidity_2m (%)  apparent_temperature (°C)  \
# 0                      74.594444                   7.112444
# 1                      74.636111                   7.109111
# 2                      74.793056                   7.096556
# 3                      74.836111                   7.093111
# 4                      74.877778                   7.089778
# ...                          ...                        ...
# 412796                 64.878333                  28.051333
# 412797                 64.904167                  28.061667
# 412798                 64.929167                  28.071667
# 412799                 64.955000                  28.082000
# 412800                 64.995000                  28.101500
#
#         precipitation (mm)  cloud_cover (%)  wind_speed_10m (km/h)  \
# 0                 0.243778       100.000000              25.006000
# 1                 0.245444       100.000000              24.991000
# 2                 0.251722       100.000000              24.934500
# 3                 0.253444       100.000000              24.919000
# 4                 0.255111       100.000000              24.904000
# ...                    ...              ...                    ...
# 412796            0.004056         9.865556               8.635222
# 412797            0.003194         9.469444               8.585278
# 412798            0.002361         9.086111               8.536944
# 412799            0.001500         8.690000               8.487000
# 412800            0.000000         8.017500               8.400750
#
#         shortwave_radiation (W/m²)  is_day ()
# 0                        49.373333        1.0
# 1                        49.273333        1.0
# 2                        48.896667        1.0
# 3                        48.793333        1.0
# 4                        48.693333        1.0
# ...                            ...        ...
# 412796                  621.015000        1.0
# 412797                  620.162500        1.0
# 412798                  619.337500        1.0
# 412799                  618.485000        1.0
# 412800                  616.960000        1.0
#
# [412801 rows x 15 columns]
